# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get("https://panchitoverduleria.cl/categoria-producto/legumbres/")

page

page.status_code

page.content

soup = BeautifulSoup(page.content, 'html.parser')

print(f'page: \n{soup.prettify()}')
# Out:
# page:
# <!DOCTYPE html>
# <!--[if IE 7]>
# <html class="ie ie7" lang="es" xmlns:og="http://ogp.me/ns#" xmlns:fb="http://ogp.me/ns/fb#">
# <![endif]-->
# <!--[if IE 8]>
# <html class="ie ie8" lang="es" xmlns:og="http://ogp.me/ns#" xmlns:fb="http://ogp.me/ns/fb#">
# <![endif]-->
# <!--[if !(IE 7) | !(IE 8) ]><!-->
# <html lang="es" xmlns:fb="http://ogp.me/ns/fb#" xmlns:og="http://ogp.me/ns#">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport">
#    <link href="https://gmpg.org/xfn/11" rel="profile"/>
#    <link href="https://panchitoverduleria.cl/xmlrpc.php" rel="pingback"/>
#    <title>
#     Legumbres – Panchito Verduleria
#    </title>
#    <meta content="max-image-preview:large" name="robots"/>
#    <link href="//fonts.googleapis.com" rel="dns-prefetch">
#     <link href="//s.w.org" rel="dns-prefetch">
# ...

# %%
page.status_code
# Out:
# 200

# %%
all_products = soup.find_all(class_="products row inline-row columns-3")

print(all_products)
# Out:
# [<div class="products row inline-row columns-3">
# <div class="inline-column col-sm-4 col-xs-6 first product type-product post-1247 status-publish instock product_cat-legumbres product_tag-legumbres product_tag-panchito-verduleria has-post-thumbnail shipping-taxable purchasable product-type-simple">
# <div class="product-inner centered-box">
# <a class="product-image" href="https://panchitoverduleria.cl/producto/arvejas-partidas-500-gramos/">
# <div class="product-labels"></div>
# ...

# %%
all_products = soup.find_all(class_="product-info clearfix")

#print(all_products)

for products in all_products:

    name_products = products.find(class_="product-title title-h6")
    price=products.find(class_="product-price")

    print(name_products.string)
# Out:
# Arvejas partidas 500 gramos
# Garbanzos 500 gramos
# Lentejas 500 gramos
# Porotos Burros 500 gramos
# Porotos Negros 500 gramos
# Porotos Payar 500 gramos
# Porotos Rojos 500 gramos

# %%
all_products = soup.find_all(class_="product-info clearfix")

#print(all_products)

for products in all_products:

    name_products = products.find(class_="product-title title-h6")
    price = products.find(class_="price")

    print(name_products.string)
    print(price)
# Out:
# Arvejas partidas 500 gramos
# <span class="price"><span class="woocommerce-Price-amount amount"><bdi><span class="woocommerce-Price-currencySymbol">$</span>1.000</bdi></span></span>
# Garbanzos 500 gramos
# <span class="price"><span class="woocommerce-Price-amount amount"><bdi><span class="woocommerce-Price-currencySymbol">$</span>1.290</bdi></span></span>
# Lentejas 500 gramos
# <span class="price"><span class="woocommerce-Price-amount amount"><bdi><span class="woocommerce-Price-currencySymbol">$</span>1.500</bdi></span></span>
# Porotos Burros 500 gramos
# <span class="price"><span class="woocommerce-Price-amount amount"><bdi><span class="woocommerce-Price-currencySymbol">$</span>1.500</bdi></span></span>
# Porotos Negros 500 gramos
# <span class="price"><span class="woocommerce-Price-amount amount"><bdi><span class="woocommerce-Price-currencySymbol">$</span>1.500</bdi></span></span>
# Porotos Payar 500 gramos
# ...
